# %%
import pandas as pd

# %%
pd.options.display.max_columns = None

# %%
suscriptions_file = '../data/suscripciones.csv'
suscriptions = pd.read_csv(suscriptions_file)
suscriptions
# Out:
#                               cod_local  id_suscripcion estado_suscripcion  \
# 0      1721f6c9eb164163a3e0fa1211d82dc4           10203           canceled
# 1      816d051601d84300815187c84eacfa6c           10306           canceled
# 2                                666173           10623           canceled
# 3      4ba25782c7624147bc5f2313e5c5a528           10872           canceled
# 4      7214e4f85b6d4cd682a6dc8a77ca653b           11136           canceled
# ...                                 ...             ...                ...
# 10740  fdd81fc7f4d74c19b2b771a38ce4d37e           83294             active
# 10741  ece8c1708a914808a0322f8047a0dc8a           85315             active
# 10742  1cebde9c62784f79a27216562942d1f5           86521           canceled
# 10743  4dc64b016741482dab474a50b4e803be           87929             active
# 10744  d7087e42acb949dc8200d496ec897c4c           89194             active
#
# ...

# %%
suscriptions.shape
# Out:
# (10745, 11)

# %%
suscriptions.isna().sum().sort_values(ascending = False)
# Out:
# id_producto            61
# referencia_producto    61
# fecha_fin               0
# fecha_inicio            0
# fecha_modificacion      0
# fecha_creacion          0
# autorenovable           0
# periodicidad            0
# estado_suscripcion      0
# id_suscripcion          0
# cod_local               0
# dtype: int64

# %%
suscriptions = suscriptions.dropna()
suscriptions
# Out:
#                               cod_local  id_suscripcion estado_suscripcion  \
# 0      1721f6c9eb164163a3e0fa1211d82dc4           10203           canceled
# 1      816d051601d84300815187c84eacfa6c           10306           canceled
# 2                                666173           10623           canceled
# 3      4ba25782c7624147bc5f2313e5c5a528           10872           canceled
# 4      7214e4f85b6d4cd682a6dc8a77ca653b           11136           canceled
# ...                                 ...             ...                ...
# 10740  fdd81fc7f4d74c19b2b771a38ce4d37e           83294             active
# 10741  ece8c1708a914808a0322f8047a0dc8a           85315             active
# 10742  1cebde9c62784f79a27216562942d1f5           86521           canceled
# 10743  4dc64b016741482dab474a50b4e803be           87929             active
# 10744  d7087e42acb949dc8200d496ec897c4c           89194             active
#
# ...

# %%
suscriptions['referencia_producto'].value_counts()
# Out:
# pack-on-diariomontanes                                             3026
# pack-on-diariomontanes-anual                                       1163
# suscripcion-on-eldiariomontanes-primermesgratis                     854
# pack-on-2-meses-gratis-eldiariomontanes                             720
# pack-on-diariomontanes-anual-2020                                   657
# pack-on-diariomontanes-primer-mes-1-euro-verano-2020                605
# pack-on-diariomontanes-OFERTA VERANO                                590
# SUSCRIPCIÓN- EL DIARIO MONTAÑÉS 4º aniversario                      496
# pack-on-diariomontanes-dos-meses-tercer-aniversario                 338
# 3mxe-3moferta-on-3m-cap-30d-201120-EDIA                             333
# suscripcion-on-diariomontanes-trimestral-noviembre-promoción-20     156
# pack-on-anual-tucocinatradicional                                   149
# pack-on-anual-tucocinatradicional-diciembre                         121
# ...

# %%
suscriptions['cod_local'].value_counts()
# Out:
# b78d22bcb585412da99467f1410e8be0    12
# 806730                               8
# 934909fdf0f64e92b8f2d5f19d43bccf     8
# 269599da76694b3ebda650019c8ed5b3     7
# 9c04399d319b40a2857db1464d5eaee7     7
#                                     ..
# a83a429f77544dcc902bdde0c0755176     1
# 615258                               1
# 11a7becfb3ab4b798727f4fcf316e087     1
# ebc40e556d7f4a86a8f45a3547da7165     1
# 1a85b2f5789042f5bf9c873f8772c248     1
# Name: cod_local, Length: 8170, dtype: int64

# %%
suscriptions[suscriptions['cod_local'] == '9c04399d319b40a2857db1464d5eaee7'].sort_values('fecha_fin')
# Out:
#                              cod_local  id_suscripcion estado_suscripcion  \
# 7201  9c04399d319b40a2857db1464d5eaee7           10380           canceled
# 2811  9c04399d319b40a2857db1464d5eaee7           14543           canceled
# 6426  9c04399d319b40a2857db1464d5eaee7           15502           canceled
# 6269  9c04399d319b40a2857db1464d5eaee7           26797           canceled
# 5744  9c04399d319b40a2857db1464d5eaee7           38350           canceled
# 4566  9c04399d319b40a2857db1464d5eaee7           51774           canceled
# 9543  9c04399d319b40a2857db1464d5eaee7           78323             active
#
#      periodicidad                   referencia_producto  id_producto  \
# 7201      Mensual                pack-on-diariomontanes      82063.0
# 2811      Mensual                pack-on-diariomontanes      82063.0
# 6426      Mensual                pack-on-diariomontanes      82063.0
# 6269      Mensual  pack-on-diariomontanes-dos meses 1 €      90593.0
# ...

# %%
suscriptions[suscriptions['estado_suscripcion'] == 'active']['periodicidad'].value_counts()
# Out:
# Mensual       2708
# Anual         2260
# Trimestral     494
# Name: periodicidad, dtype: int64
